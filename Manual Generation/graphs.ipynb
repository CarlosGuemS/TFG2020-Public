# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Code to generate the graphs

# %%
# Method labels
labels = ["Base", "Base + TD", "Base + EMI", "Base + TD\n+ EMI"]
x = np.arange(len(labels))

# %%
width = 0.15  # the width of the bars
sep_constant = 0.02

fig, ax = plt.subplots(figsize = (12, 8))


#Data
rectsOA = ax.bar(x - 3*width/2-1.5*sep_constant, data_OA, width, label='OA')
rectsOAE = ax.bar(x - width/2-0.5*sep_constant, data_OAE, width, label='OA-E')
rectsIWA = ax.bar(x + width/2+0.5*sep_constant, data_IWA, width, label='IWA')
rectsDLR = ax.bar(x + 3*width/2+1.5*sep_constant, data_DLR, width, label='DLR')

#The graph itself
ax.set_ylabel('F-Score (%)', size="x-large")
ax.set_xlabel('Set of features', size="x-large")
#ax.set_title(graph_title)
ax.set_xticks(x)
ax.set_xticklabels(labels, size="x-large")
ax.legend(prop={'size': 12})
legend = ax.get_legend()
legend.set_title("Datasets")

fig.tight_layout()

plt.savefig(file_title, format='pdf')
plt.show()

# %% [markdown]
# ## Naive Bayes
#
# Graph for Fscore

# %%
data_OA = [0.7139, 0.5744, 0.5404, 0.4255]
data_OAE = [0.7255, 0.6649, 0.5751, 0.4737]
data_IWA = [0.5647, 0.5661, 0.3887, 0.3416]
data_DLR = [0.5295, 0.1996, 0.2002, 0.1113]
file_title = "Naive Bayes Fscore.pdf"
graph_title = "F-Score obtained by a Naive Bayes classifier by dataset and set of features"

# %% [markdown]
# ## SVM
#
# Graph for Fscore

# %%
data_OA = [0.9041, 0.8662, 0.8635, 0.814]
data_OAE = [0.926, 0.8927, 0.887, 0.8422]
data_IWA = [0.8765, 0.8049, 0.7628, 0.653]
data_DLR = [0.5668, 0.5033, 0.5471, 0.4485]
file_title = "SVM Fscore.pdf"
graph_title = "F-Score obtained by a SVM classifier by dataset and set of features"
